# %%
from IndusDC import clean_data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20708/830001427.py in <module>
# ----> 1 from IndusDC import clean_data
#
# c:\Users\lenovo\Documents\GitHub\FYP\IndusDC.py in <module>
#     105     write_to_onedrive(new_df, "merged_clean_data.xlsx") #add write to one drive in med ner
#     106
# --> 107 clean_data()
#
# c:\Users\lenovo\Documents\GitHub\FYP\IndusDC.py in clean_data()
#       9     onedrive_link = 'https://1drv.ms/x/s!AsCp_kE1E5Md6hQevRHs-ptqyPlE?e=xtMYOg' #pass actual dirty merged file
#      10     link = create_onedrive_directdownload(onedrive_link)
# ---> 11     data = pd.read_excel(link)
#      12
#      13     #Convert Excel to DataFrame
#
# ...

# %%
clean_data()
